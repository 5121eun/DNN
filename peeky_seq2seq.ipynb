# %%
from dataset import sequence
import numpy as np
import time
import matplotlib.pyplot as plt

# %%
class PeekySeq2seqlm:
    
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        
        rn = np.random.randn
        enc_embed = (rn(V, D) / 100).astype('f')
        enc_lstmWx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        enc_lstmWh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        enc_lstmb = np.zeros(4 * H).astype('f')
        
        dec_embed = (rn(V, D) / 100).astype('f')
        dec_lstmWx = (rn(H + D, 4 * H) / np.sqrt(D)).astype('f')
        dec_lstmWh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        dec_lstmb = np.zeros(4 * H).astype('f')
        dec_affineW = (rn(H + H, V) / np.sqrt(H)).astype('f')
        dec_affineb = np.zeros(V).astype('f')
        
        self.params = [enc_embed, enc_lstmWx, enc_lstmWh, enc_lstmb, \
            dec_embed, dec_lstmWx, dec_lstmWh, dec_lstmb, dec_affineW, dec_affineb]
        
        self.grads = []
        self.enc_lstm = [] 
        self.dec_lstm = []
        
        self.time_idx = 0
        self.vocab_size = vocab_size
        self.wordvec_size = wordvec_size
        self.hidden_size = hidden_size
        
        self.beta1 = 0.9
        self.beta2 = 0.999
        self.iter = 0
        self.m = None
        self.v = None

        
    def forward(self, enc_xs, ts):
        enc_embed, enc_lstmWx, enc_lstmWh, enc_lstmb, \
            dec_embed, dec_lstmWx, dec_lstmWh, dec_lstmb, dec_affineW, dec_affineb = self.params
        
        self.enc_lstm = []
        self.dec_lstm = []
        
        dec_xs = ts[:, :-1]
        dec_ts = ts[:, 1:]
        
        batch_size, enc_time_size = enc_xs.shape
        dec_time_size = dec_xs.shape[1]
        
        hidden_size = self.hidden_size
               
        ####################### ENCODER #######################
        
        h_prev = np.zeros((batch_size, hidden_size), dtype='f')
        c_prev = np.zeros((batch_size, hidden_size), dtype='f')
        enc_hs = np.zeros((batch_size, enc_time_size, hidden_size), dtype='f')
        for t in range(enc_time_size):
            # embed
            emb_out = enc_embed[enc_xs[:, t]]

            # lstm
            A = np.matmul(emb_out, enc_lstmWx) + np.matmul(h_prev, enc_lstmWh) + enc_lstmb
            f = A[:, :hidden_size]
            g = A[:, hidden_size: 2*hidden_size]
            i = A[:, 2*hidden_size: 3*hidden_size]
            o = A[:, 3*hidden_size:]

            f = self.sigmoid(f)
            g = np.tanh(g)
            i = self.sigmoid(i)
            o = self.sigmoid(o)

            c_next = f * c_prev + g * i
            h_next = o * np.tanh(c_next)
            
            enc_hs[:, t, :] = h_next
            
            self.enc_lstm.append((emb_out, h_prev, c_prev, f, g, i, o, c_next, h_next))
            
            c_prev = c_next
            h_prev = h_next
            
        h = h_prev
        ####################### DECODER #######################
        
        c_prev = np.zeros((batch_size, hidden_size), dtype='f')
        dec_hs = np.zeros((batch_size, dec_time_size, hidden_size), dtype='f')
        for t in range(dec_time_size):
            # embed
            emb_out = dec_embed[dec_xs[:, t]]
            emb_out = np.concatenate((h, emb_out), axis=1)
            
            # lstm
            A = np.matmul(emb_out, dec_lstmWx) + np.matmul(h_prev, dec_lstmWh) + dec_lstmb
            f = A[:, :hidden_size]
            g = A[:, hidden_size: 2*hidden_size]
            i = A[:, 2*hidden_size: 3*hidden_size]
            o = A[:, 3*hidden_size:]

            f = self.sigmoid(f)
            g = np.tanh(g)
            i = self.sigmoid(i)
            o = self.sigmoid(o)

            c_next = f * c_prev + g * i
            h_next = o * np.tanh(c_next)
            
            dec_hs[:, t, :] = h_next
            
            self.dec_lstm.append((emb_out, h_prev, c_prev, f, g, i, o, c_next, h_next))
            c_prev = c_next
            h_prev = h_next
            
            
        # affine
        hs = np.repeat(h, dec_time_size, axis=0).reshape(batch_size, dec_time_size, hidden_size)
        dec_hs = np.concatenate((hs, dec_hs), axis=2)
        dec_hs = dec_hs.reshape(batch_size * dec_time_size, -1)
        dec_affine_out = np.matmul(dec_hs, dec_affineW) + dec_affineb
        
        # softmax
        y = self.softmax(dec_affine_out.reshape(batch_size, dec_time_size, -1))
        loss = self.getLoss(y, dec_ts)
        
        self.xs = enc_xs, enc_hs, dec_xs, dec_hs, dec_affine_out, y
        self.ts = dec_ts
        return loss
        
    def backward(self):
        enc_embed, enc_lstmWx, enc_lstmWh, enc_lstmb, \
            dec_embed, dec_lstmWx, dec_lstmWh, dec_lstmb, dec_affineW, dec_affineb = self.params
        enc_xs, enc_hs, dec_xs, dec_hs, dec_affine_out, y = self.xs
        dec_ts = self.ts
        
        vocab_size = self.vocab_size        
        wordvec_size = self.wordvec_size
        batch_size, enc_time_size = enc_xs.shape
        dec_time_size = dec_xs.shape[1]
        
        ####################### DECODER #######################
        
        # softmax
        y = y.reshape(batch_size * dec_time_size, -1)
        y[np.arange(batch_size * dec_time_size), dec_ts.reshape(batch_size * dec_time_size)] -= 1
        soft_dout = y
        
        # affine
        dec_hs = dec_hs.reshape(batch_size * dec_time_size, -1)
        dec_affine_dout = np.matmul(soft_dout, dec_affineW.T).reshape(batch_size, dec_time_size, -1) 
        dec_affinedW = np.matmul(dec_hs.T, soft_dout) 
        dec_affinedb = np.sum(soft_dout, axis=0)       
        
        dec_affine_dout, dhs0 = dec_affine_dout[:, :, hidden_size:], dec_affine_dout[:, :, :hidden_size]

        # lstm
        dec_lstmdWx = np.zeros_like(dec_lstmWx)
        dec_lstmdWh = np.zeros_like(dec_lstmWh)
        dec_lstmdb = np.zeros_like(dec_lstmb)
        
        dec_lstm_douts = np.empty((batch_size, dec_time_size, hidden_size + wordvec_size), dtype='f')
        dh, dc = 0, 0
        for t in reversed(range(dec_time_size)):            
            emb_out, h_prev, c_prev, f, g, i, o, c_next, _ = self.dec_lstm[t]
            dh_next = dec_affine_dout[:, t, :] + dh
            dc_next = dc

            tanh_c_next = np.tanh(c_next)
            
            ds = dc_next + (dh_next * o) * (1 - tanh_c_next ** 2)
            
            dc_prev = ds * f
            
            di = ds * g
            df = ds * c_prev
            do = dh_next * tanh_c_next
            dg = ds * i
            
            di *= i * (1 - i)
            df *= f * (1 - f)
            do *= o * (1 - o)
            dg *= (1 - g ** 2)
            
            dA = np.hstack((df, dg, di, do))
            
            dWh = np.matmul(h_prev.T, dA)
            dWx = np.matmul(emb_out.T, dA)
            db = np.sum(dA, axis=0)
            
            dec_lstm_douts[:, t, :] = np.matmul(dA, dec_lstmWx.T)
            dh_prev = np.matmul(dA, dec_lstmWh.T)
        
            dec_lstmdWx += dWx
            dec_lstmdWh += dWh
            dec_lstmdb += db
            dh = dh_prev
            dc = dc_prev
            
        dec_lstm_douts, dhs1 = dec_lstm_douts[:, :, hidden_size:], dec_lstm_douts[:, :, :hidden_size]
        dhs = dhs0 + dhs1
        dh += np.sum(dhs, axis=1)
        
        # embed
        dec_embed_dout = np.zeros_like(dec_embed)
        for t in range(dec_time_size):
            np.add.at(dec_embed_dout, dec_xs[:, t], dec_lstm_douts[:, t, :])
            
        ####################### ENCODER #######################
        
        # lstm
        enc_lstmdWx = np.zeros_like(enc_lstmWx)
        enc_lstmdWh = np.zeros_like(enc_lstmWh)
        enc_lstmdb = np.zeros_like(enc_lstmb)
        
        enc_lstm_douts = np.empty((batch_size, enc_time_size, wordvec_size), dtype='f')
        dc = 0
        for t in reversed(range(enc_time_size)):            
            emb_out, h_prev, c_prev, f, g, i, o, c_next, _ = self.enc_lstm[t]
            dh_next = dh
            dc_next = dc

            tanh_c_next = np.tanh(c_next)
            
            ds = dc_next + (dh_next * o) * (1 - tanh_c_next ** 2)
            
            dc_prev = ds * f
            
            di = ds * g
            df = ds * c_prev
            do = dh_next * tanh_c_next
            dg = ds * i
            
            di *= i * (1 - i)
            df *= f * (1 - f)
            do *= o * (1 - o)
            dg *= (1 - g ** 2)
            
            dA = np.hstack((df, dg, di, do))
            
            dWh = np.matmul(h_prev.T, dA)
            dWx = np.matmul(emb_out.T, dA)
            db = np.sum(dA, axis=0)
            
            enc_lstm_douts[:, t, :] = np.matmul(dA, enc_lstmWx.T)
            dh_prev = np.matmul(dA, enc_lstmWh.T)
        
            enc_lstmdWx += dWx
            enc_lstmdWh += dWh
            enc_lstmdb += db
            dh = dh_prev
            dc = dc_prev        
        
        # embed
        enc_embed_dout = np.zeros_like(enc_embed)
        for t in range(enc_time_size):
            np.add.at(enc_embed_dout, enc_xs[:, t], enc_lstm_douts[:, t, :])
        
        self.grads = enc_embed_dout, enc_lstmdWx, enc_lstmdWh, enc_lstmdb, \
            dec_embed_dout, dec_lstmdWx, dec_lstmdWh, dec_lstmdb, dec_affinedW, dec_affinedb
        
    def softmax(self, y):
        y = y - np.max(y)
        y = np.exp(y)
        y = y / y.sum(axis=-1, keepdims=True)
        return y
    
    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))
    
    def getLoss(self, y, t):
        N, T, V = y.shape

        y = y.reshape(N * T, V)
        t = t.reshape(N * T)

        ls = np.log(y[np.arange(N * T), t])
        return -np.sum(ls) / (N * T)
            
    def updateAdam(self, lr):
        params = self.params
        grads = self.grads
        
        if self.m is None:
            self.m, self.v = [], []
            for param in params:
                self.m.append(np.zeros_like(param))
                self.v.append(np.zeros_like(param))
                
        self.iter += 1
        lr_t = lr * np.sqrt(1.0 - self.beta2**self.iter) / (1.0 - self.beta1**self.iter)
        
        for i in range(len(params)):
            self.m[i] += (1 - self.beta1) * (grads[i] - self.m[i])
            self.v[i] += (1 - self.beta2) * (grads[i]**2 - self.v[i])
            
            params[i] -= lr_t * self.m[i] / (np.sqrt(self.v[i]) + 1e-7)
        self.params = params
        
    def clip_grads(self, max_norm):
        grads = self.grads
        total_norm = 0
        
        for grad in grads:
            total_norm += np.sum(grad**2)
            
        total_norm = np.sqrt(total_norm)
        
        rate = max_norm / (total_norm + 1e-6)
        
        if rate  < 1:
            for grad in grads:
                grad *= rate
        self.grads = grads
            
    def generate(self, xs, start_id, sample_size):
        enc_embed, enc_lstmWx, enc_lstmWh, enc_lstmb, \
            dec_embed, dec_lstmWx, dec_lstmWh, dec_lstmb, dec_affineW, dec_affineb = self.params
        
        
        enc_time_size = xs.shape[1]
        hidden_size = self.hidden_size
        
        ####################### ENCODER #######################
        
        h_prev = np.zeros((hidden_size), dtype='f')
        c_prev = np.zeros((hidden_size), dtype='f')
        for t in range(enc_time_size):
            # embed
            emb_out = enc_embed[xs[:, t]]

            # lstm
            A = np.matmul(emb_out, enc_lstmWx) + np.matmul(h_prev, enc_lstmWh) + enc_lstmb
            f = A[:, :hidden_size]
            g = A[:, hidden_size: 2*hidden_size]
            i = A[:, 2*hidden_size: 3*hidden_size]
            o = A[:, 3*hidden_size:]

            f = self.sigmoid(f)
            g = np.tanh(g)
            i = self.sigmoid(i)
            o = self.sigmoid(o)

            c_next = f * c_prev + g * i
            h_next = o * np.tanh(c_next)
            
            c_prev = c_next
            h_prev = h_next
                        
        sampled = []
        sample_id = start_id
        
        h = h_prev
        ####################### DECODER #######################

        c_prev = np.zeros((hidden_size), dtype='f')
        for _ in range(sample_size):
            
            # embed
            emb_out = dec_embed[sample_id].reshape(1, -1)           
            emb_out = np.concatenate((h, emb_out), axis=1)

            
            # lstm
            A = np.matmul(emb_out, dec_lstmWx) + np.matmul(h_prev, dec_lstmWh) + dec_lstmb
            f = A[:, :hidden_size]
            g = A[:, hidden_size: 2*hidden_size]
            i = A[:, 2*hidden_size: 3*hidden_size]
            o = A[:, 3*hidden_size:]

            f = self.sigmoid(f)
            g = np.tanh(g)
            i = self.sigmoid(i)
            o = self.sigmoid(o)

            c_next = f * c_prev + g * i
            h_next = o * np.tanh(c_next)

            c_prev = c_next
            h_prev = h_next
            
            # affine
            add_h = np.concatenate((h, h_next), axis=1)
            dec_affine_out = np.matmul(add_h, dec_affineW) + dec_affineb
            
            # softmax
            y = self.softmax(dec_affine_out)
            sample_id = np.argmax(y.flatten())
            sampled.append(int(sample_id))
        
        return sampled
            
    def eval_seq2seq(self, question, correct, id_to_char,
                     verbos=False, is_reverse=False):
        correct = correct.flatten()
        start_id = correct[0]
        correct = correct[1:]
        guess = self.generate(question, start_id, len(correct))

        question = ''.join([id_to_char[int(c)] for c in question.flatten()])
        correct = ''.join([id_to_char[int(c)] for c in correct])
        guess = ''.join([id_to_char[int(c)] for c in guess])

        if verbos:
            if is_reverse:
                question = question[::-1]

            print('Q', question)
            print('T', correct)

            if correct == guess:
                mark = 'O'
                print(mark + ' ' + guess)
            else:
                mark = 'X'
                print(mark + ' ' + guess)
            print('---')

        return 1 if guess == correct else 0

# %%
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
x_train = x_train[:, ::-1]
x_test = x_test[:, ::-1]
char_to_id, id_to_char = sequence.get_vocab()

# %%
vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0
data_size = len(x_train)
learning_rate = 0.001
max_grad = 5.0
data_size = len(x_train)
max_iters = data_size // batch_size

# %%
model = PeekySeq2seqlm(vocab_size, wordvec_size, hidden_size)

# %%
acc_list = []
loss_list = []
start_time = time.time()
total_loss, loss_count = 0, 0

for epoch in range(max_epoch):
    idx = np.random.permutation(np.arange(data_size))
    x_train = x_train[idx]
    t_train = t_train[idx]
    
    for iters in range(max_iters):
        batch_x = x_train[(iters * batch_size) : (iters + 1) * batch_size]
        batch_t = t_train[(iters * batch_size) : (iters + 1) * batch_size]
        
        loss = model.forward(batch_x, batch_t)
        model.backward()
        model.clip_grads(max_grad)
        model.updateAdam(learning_rate)
        
        total_loss += loss
        loss_count += 1
        
        if iters % 20 == 0:
            avg_loss = total_loss / loss_count
            elapsed_time = time.time() - start_time
            print('| epoch %d |  iters %d / %d | time %d[s] | loss %.2f'
                % (epoch + 1, iters + 1, max_iters, elapsed_time, avg_loss))
            loss_list.append(avg_loss)
            total_loss, loss_count = 0, 0
            
    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += model.eval_seq2seq(question, correct, id_to_char, verbose)
    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)
    print('accuracy %.3f%%' % (acc * 100))
# Out:
# | epoch 1 |  iters 1 / 351 | time 0[s] | loss 2.56
# | epoch 1 |  iters 21 / 351 | time 2[s] | loss 2.44
# | epoch 1 |  iters 41 / 351 | time 3[s] | loss 2.15
# | epoch 1 |  iters 61 / 351 | time 6[s] | loss 1.93
# | epoch 1 |  iters 81 / 351 | time 8[s] | loss 1.81
# | epoch 1 |  iters 101 / 351 | time 11[s] | loss 1.80
# | epoch 1 |  iters 121 / 351 | time 13[s] | loss 1.80
# | epoch 1 |  iters 141 / 351 | time 15[s] | loss 1.78
# | epoch 1 |  iters 161 / 351 | time 17[s] | loss 1.77
# | epoch 1 |  iters 181 / 351 | time 20[s] | loss 1.76
# | epoch 1 |  iters 201 / 351 | time 22[s] | loss 1.76
# | epoch 1 |  iters 221 / 351 | time 25[s] | loss 1.75
# | epoch 1 |  iters 241 / 351 | time 28[s] | loss 1.75
# | epoch 1 |  iters 261 / 351 | time 31[s] | loss 1.73
# | epoch 1 |  iters 281 / 351 | time 33[s] | loss 1.73
# | epoch 1 |  iters 301 / 351 | time 36[s] | loss 1.72
# | epoch 1 |  iters 321 / 351 | time 39[s] | loss 1.71
# | epoch 1 |  iters 341 / 351 | time 41[s] | loss 1.71
# Q   58+77
# T 162
# X 107
# ---
# Q 461+579
# T 1139
# X 1011
# ---
# Q  48+285
# T 666
# X 102
# ---
# Q   551+8
# T 163
# X 101
# ---
# Q  55+763
# T 422
# X 777
# ---
# Q 752+006
# T 857
# X 1011
# ---
# Q 292+167
# T 1053
# X 1011
# ---
# Q 795+038
# T 1427
# X 1111
# ---
# Q  838+62
# T 864
# X 222
# ---
# Q  39+341
# T 236
# X 222
# ---
# accuracy 0.260%
# | epoch 2 |  iters 1 / 351 | time 57[s] | loss 1.70
# | epoch 2 |  iters 21 / 351 | time 59[s] | loss 1.69
# | epoch 2 |  iters 41 / 351 | time 60[s] | loss 1.68
# | epoch 2 |  iters 61 / 351 | time 62[s] | loss 1.68
# | epoch 2 |  iters 81 / 351 | time 64[s] | loss 1.66
# | epoch 2 |  iters 101 / 351 | time 66[s] | loss 1.66
# | epoch 2 |  iters 121 / 351 | time 67[s] | loss 1.65
# | epoch 2 |  iters 141 / 351 | time 69[s] | loss 1.64
# | epoch 2 |  iters 161 / 351 | time 71[s] | loss 1.62
# | epoch 2 |  iters 181 / 351 | time 72[s] | loss 1.61
# | epoch 2 |  iters 201 / 351 | time 74[s] | loss 1.61
# | epoch 2 |  iters 221 / 351 | time 75[s] | loss 1.59
# | epoch 2 |  iters 241 / 351 | time 77[s] | loss 1.58
# | epoch 2 |  iters 261 / 351 | time 79[s] | loss 1.57
# | epoch 2 |  iters 281 / 351 | time 80[s] | loss 1.56
# | epoch 2 |  iters 301 / 351 | time 82[s] | loss 1.55
# | epoch 2 |  iters 321 / 351 | time 83[s] | loss 1.53
# | epoch 2 |  iters 341 / 351 | time 85[s] | loss 1.52
# Q   58+77
# T 162
# X 777
# ---
# Q 461+579
# T 1139
# X 1001
# ---
# Q  48+285
# T 666
# X 632
# ---
# Q   551+8
# T 163
# X 122
# ---
# Q  55+763
# T 422
# X 610
# ---
# Q 752+006
# T 857
# X 918
# ---
# Q 292+167
# T 1053
# X 1008
# ---
# Q 795+038
# T 1427
# X 1660
# ---
# Q  838+62
# T 864
# X 708
# ---
# Q  39+341
# T 236
# X 444
# ---
# accuracy 0.700%
# | epoch 3 |  iters 1 / 351 | time 101[s] | loss 1.50
# | epoch 3 |  iters 21 / 351 | time 103[s] | loss 1.49
# | epoch 3 |  iters 41 / 351 | time 105[s] | loss 1.47
# | epoch 3 |  iters 61 / 351 | time 107[s] | loss 1.45
# | epoch 3 |  iters 81 / 351 | time 108[s] | loss 1.43
# | epoch 3 |  iters 101 / 351 | time 110[s] | loss 1.42
# | epoch 3 |  iters 121 / 351 | time 111[s] | loss 1.40
# | epoch 3 |  iters 141 / 351 | time 113[s] | loss 1.39
# | epoch 3 |  iters 161 / 351 | time 115[s] | loss 1.38
# | epoch 3 |  iters 181 / 351 | time 117[s] | loss 1.35
# | epoch 3 |  iters 201 / 351 | time 119[s] | loss 1.34
# | epoch 3 |  iters 221 / 351 | time 120[s] | loss 1.33
# | epoch 3 |  iters 241 / 351 | time 122[s] | loss 1.31
# | epoch 3 |  iters 261 / 351 | time 124[s] | loss 1.30
# | epoch 3 |  iters 281 / 351 | time 125[s] | loss 1.28
# | epoch 3 |  iters 301 / 351 | time 127[s] | loss 1.28
# | epoch 3 |  iters 321 / 351 | time 128[s] | loss 1.25
# | epoch 3 |  iters 341 / 351 | time 130[s] | loss 1.25
# Q   58+77
# T 162
# X 166
# ---
# Q 461+579
# T 1139
# X 1109
# ---
# Q  48+285
# T 666
# X 644
# ---
# Q   551+8
# T 163
# X 166
# ---
# Q  55+763
# T 422
# X 413
# ---
# Q 752+006
# T 857
# X 900
# ---
# Q 292+167
# T 1053
# X 1021
# ---
# Q 795+038
# T 1427
# X 1401
# ---
# Q  838+62
# T 864
# X 890
# ---
# Q  39+341
# T 236
# X 213
# ---
# accuracy 2.920%
# | epoch 4 |  iters 1 / 351 | time 145[s] | loss 1.23
# | epoch 4 |  iters 21 / 351 | time 146[s] | loss 1.22
# | epoch 4 |  iters 41 / 351 | time 148[s] | loss 1.21
# | epoch 4 |  iters 61 / 351 | time 150[s] | loss 1.19
# | epoch 4 |  iters 81 / 351 | time 151[s] | loss 1.18
# | epoch 4 |  iters 101 / 351 | time 153[s] | loss 1.17
# | epoch 4 |  iters 121 / 351 | time 154[s] | loss 1.16
# | epoch 4 |  iters 141 / 351 | time 156[s] | loss 1.16
# | epoch 4 |  iters 161 / 351 | time 158[s] | loss 1.14
# | epoch 4 |  iters 181 / 351 | time 160[s] | loss 1.13
# | epoch 4 |  iters 201 / 351 | time 161[s] | loss 1.12
# | epoch 4 |  iters 221 / 351 | time 163[s] | loss 1.11
# | epoch 4 |  iters 241 / 351 | time 165[s] | loss 1.10
# | epoch 4 |  iters 261 / 351 | time 167[s] | loss 1.08
# | epoch 4 |  iters 281 / 351 | time 168[s] | loss 1.07
# | epoch 4 |  iters 301 / 351 | time 170[s] | loss 1.07
# | epoch 4 |  iters 321 / 351 | time 172[s] | loss 1.05
# | epoch 4 |  iters 341 / 351 | time 173[s] | loss 1.04
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# X 1110
# ---
# Q  48+285
# T 666
# X 657
# ---
# Q   551+8
# T 163
# X 155
# ---
# Q  55+763
# T 422
# X 423
# ---
# Q 752+006
# T 857
# X 870
# ---
# Q 292+167
# T 1053
# X 1027
# ---
# Q 795+038
# T 1427
# X 1379
# ---
# Q  838+62
# T 864
# X 879
# ---
# Q  39+341
# T 236
# X 223
# ---
# accuracy 6.140%
# | epoch 5 |  iters 1 / 351 | time 186[s] | loss 1.02
# | epoch 5 |  iters 21 / 351 | time 188[s] | loss 1.02
# | epoch 5 |  iters 41 / 351 | time 189[s] | loss 1.00
# | epoch 5 |  iters 61 / 351 | time 191[s] | loss 1.00
# | epoch 5 |  iters 81 / 351 | time 192[s] | loss 0.99
# | epoch 5 |  iters 101 / 351 | time 194[s] | loss 0.97
# | epoch 5 |  iters 121 / 351 | time 196[s] | loss 0.96
# | epoch 5 |  iters 141 / 351 | time 197[s] | loss 0.94
# | epoch 5 |  iters 161 / 351 | time 199[s] | loss 0.94
# | epoch 5 |  iters 181 / 351 | time 201[s] | loss 0.93
# | epoch 5 |  iters 201 / 351 | time 202[s] | loss 0.91
# | epoch 5 |  iters 221 / 351 | time 204[s] | loss 0.90
# | epoch 5 |  iters 241 / 351 | time 205[s] | loss 0.88
# | epoch 5 |  iters 261 / 351 | time 207[s] | loss 0.88
# | epoch 5 |  iters 281 / 351 | time 209[s] | loss 0.86
# | epoch 5 |  iters 301 / 351 | time 210[s] | loss 0.85
# | epoch 5 |  iters 321 / 351 | time 212[s] | loss 0.83
# | epoch 5 |  iters 341 / 351 | time 214[s] | loss 0.82
# Q   58+77
# T 162
# X 163
# ---
# Q 461+579
# T 1139
# X 1149
# ---
# Q  48+285
# T 666
# X 667
# ---
# Q   551+8
# T 163
# X 166
# ---
# Q  55+763
# T 422
# X 421
# ---
# Q 752+006
# T 857
# X 861
# ---
# Q 292+167
# T 1053
# X 1036
# ---
# Q 795+038
# T 1427
# X 1418
# ---
# Q  838+62
# T 864
# X 873
# ---
# Q  39+341
# T 236
# X 233
# ---
# accuracy 15.960%
# | epoch 6 |  iters 1 / 351 | time 225[s] | loss 0.80
# | epoch 6 |  iters 21 / 351 | time 227[s] | loss 0.79
# | epoch 6 |  iters 41 / 351 | time 229[s] | loss 0.77
# | epoch 6 |  iters 61 / 351 | time 230[s] | loss 0.75
# | epoch 6 |  iters 81 / 351 | time 232[s] | loss 0.74
# | epoch 6 |  iters 101 / 351 | time 234[s] | loss 0.73
# | epoch 6 |  iters 121 / 351 | time 235[s] | loss 0.72
# | epoch 6 |  iters 141 / 351 | time 238[s] | loss 0.71
# | epoch 6 |  iters 161 / 351 | time 241[s] | loss 0.69
# | epoch 6 |  iters 181 / 351 | time 243[s] | loss 0.67
# | epoch 6 |  iters 201 / 351 | time 245[s] | loss 0.66
# | epoch 6 |  iters 221 / 351 | time 248[s] | loss 0.64
# | epoch 6 |  iters 241 / 351 | time 249[s] | loss 0.63
# | epoch 6 |  iters 261 / 351 | time 251[s] | loss 0.61
# | epoch 6 |  iters 281 / 351 | time 253[s] | loss 0.60
# | epoch 6 |  iters 301 / 351 | time 255[s] | loss 0.59
# | epoch 6 |  iters 321 / 351 | time 257[s] | loss 0.58
# | epoch 6 |  iters 341 / 351 | time 259[s] | loss 0.56
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# X 1149
# ---
# Q  48+285
# T 666
# X 667
# ---
# Q   551+8
# T 163
# X 155
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# X 867
# ---
# Q 292+167
# T 1053
# X 1034
# ---
# Q 795+038
# T 1427
# X 1428
# ---
# Q  838+62
# T 864
# X 873
# ---
# Q  39+341
# T 236
# O 236
# ---
# accuracy 41.720%
# | epoch 7 |  iters 1 / 351 | time 274[s] | loss 0.55
# | epoch 7 |  iters 21 / 351 | time 276[s] | loss 0.53
# | epoch 7 |  iters 41 / 351 | time 278[s] | loss 0.52
# | epoch 7 |  iters 61 / 351 | time 280[s] | loss 0.51
# | epoch 7 |  iters 81 / 351 | time 282[s] | loss 0.51
# | epoch 7 |  iters 101 / 351 | time 283[s] | loss 0.50
# | epoch 7 |  iters 121 / 351 | time 285[s] | loss 0.49
# | epoch 7 |  iters 141 / 351 | time 286[s] | loss 0.48
# | epoch 7 |  iters 161 / 351 | time 288[s] | loss 0.47
# | epoch 7 |  iters 181 / 351 | time 290[s] | loss 0.46
# | epoch 7 |  iters 201 / 351 | time 291[s] | loss 0.45
# | epoch 7 |  iters 221 / 351 | time 293[s] | loss 0.43
# | epoch 7 |  iters 241 / 351 | time 294[s] | loss 0.43
# | epoch 7 |  iters 261 / 351 | time 296[s] | loss 0.42
# | epoch 7 |  iters 281 / 351 | time 298[s] | loss 0.43
# | epoch 7 |  iters 301 / 351 | time 300[s] | loss 0.40
# | epoch 7 |  iters 321 / 351 | time 301[s] | loss 0.40
# | epoch 7 |  iters 341 / 351 | time 303[s] | loss 0.40
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# X 1149
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# X 162
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# X 1043
# ---
# Q 795+038
# T 1427
# X 1428
# ---
# Q  838+62
# T 864
# X 874
# ---
# Q  39+341
# T 236
# O 236
# ---
# accuracy 65.380%
# | epoch 8 |  iters 1 / 351 | time 320[s] | loss 0.38
# | epoch 8 |  iters 21 / 351 | time 321[s] | loss 0.37
# | epoch 8 |  iters 41 / 351 | time 323[s] | loss 0.37
# | epoch 8 |  iters 61 / 351 | time 325[s] | loss 0.36
# | epoch 8 |  iters 81 / 351 | time 328[s] | loss 0.36
# | epoch 8 |  iters 101 / 351 | time 330[s] | loss 0.35
# | epoch 8 |  iters 121 / 351 | time 332[s] | loss 0.34
# | epoch 8 |  iters 141 / 351 | time 334[s] | loss 0.34
# | epoch 8 |  iters 161 / 351 | time 336[s] | loss 0.34
# | epoch 8 |  iters 181 / 351 | time 337[s] | loss 0.33
# | epoch 8 |  iters 201 / 351 | time 339[s] | loss 0.32
# | epoch 8 |  iters 221 / 351 | time 341[s] | loss 0.31
# | epoch 8 |  iters 241 / 351 | time 343[s] | loss 0.31
# | epoch 8 |  iters 261 / 351 | time 345[s] | loss 0.30
# | epoch 8 |  iters 281 / 351 | time 346[s] | loss 0.30
# | epoch 8 |  iters 301 / 351 | time 348[s] | loss 0.30
# | epoch 8 |  iters 321 / 351 | time 349[s] | loss 0.29
# | epoch 8 |  iters 341 / 351 | time 351[s] | loss 0.28
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# X 1149
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# X 154
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# accuracy 76.020%
# | epoch 9 |  iters 1 / 351 | time 366[s] | loss 0.28
# | epoch 9 |  iters 21 / 351 | time 368[s] | loss 0.27
# | epoch 9 |  iters 41 / 351 | time 370[s] | loss 0.27
# | epoch 9 |  iters 61 / 351 | time 371[s] | loss 0.26
# | epoch 9 |  iters 81 / 351 | time 373[s] | loss 0.25
# | epoch 9 |  iters 101 / 351 | time 375[s] | loss 0.26
# | epoch 9 |  iters 121 / 351 | time 377[s] | loss 0.25
# | epoch 9 |  iters 141 / 351 | time 379[s] | loss 0.24
# | epoch 9 |  iters 161 / 351 | time 381[s] | loss 0.24
# | epoch 9 |  iters 181 / 351 | time 383[s] | loss 0.24
# | epoch 9 |  iters 201 / 351 | time 384[s] | loss 0.23
# | epoch 9 |  iters 221 / 351 | time 386[s] | loss 0.24
# | epoch 9 |  iters 241 / 351 | time 388[s] | loss 0.23
# | epoch 9 |  iters 261 / 351 | time 390[s] | loss 0.22
# | epoch 9 |  iters 281 / 351 | time 392[s] | loss 0.22
# | epoch 9 |  iters 301 / 351 | time 393[s] | loss 0.22
# | epoch 9 |  iters 321 / 351 | time 395[s] | loss 0.21
# | epoch 9 |  iters 341 / 351 | time 396[s] | loss 0.21
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# X 1149
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# X 162
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# X 874
# ---
# Q  39+341
# T 236
# O 236
# ---
# accuracy 80.220%
# | epoch 10 |  iters 1 / 351 | time 411[s] | loss 0.21
# | epoch 10 |  iters 21 / 351 | time 413[s] | loss 0.21
# | epoch 10 |  iters 41 / 351 | time 415[s] | loss 0.19
# | epoch 10 |  iters 61 / 351 | time 417[s] | loss 0.20
# | epoch 10 |  iters 81 / 351 | time 418[s] | loss 0.19
# | epoch 10 |  iters 101 / 351 | time 420[s] | loss 0.19
# | epoch 10 |  iters 121 / 351 | time 422[s] | loss 0.19
# | epoch 10 |  iters 141 / 351 | time 423[s] | loss 0.18
# | epoch 10 |  iters 161 / 351 | time 425[s] | loss 0.18
# | epoch 10 |  iters 181 / 351 | time 426[s] | loss 0.18
# | epoch 10 |  iters 201 / 351 | time 428[s] | loss 0.18
# | epoch 10 |  iters 221 / 351 | time 430[s] | loss 0.17
# | epoch 10 |  iters 241 / 351 | time 432[s] | loss 0.16
# | epoch 10 |  iters 261 / 351 | time 433[s] | loss 0.17
# | epoch 10 |  iters 281 / 351 | time 435[s] | loss 0.16
# | epoch 10 |  iters 301 / 351 | time 437[s] | loss 0.16
# | epoch 10 |  iters 321 / 351 | time 438[s] | loss 0.16
# | epoch 10 |  iters 341 / 351 | time 440[s] | loss 0.16
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# accuracy 88.140%
# | epoch 11 |  iters 1 / 351 | time 456[s] | loss 0.16
# | epoch 11 |  iters 21 / 351 | time 458[s] | loss 0.15
# | epoch 11 |  iters 41 / 351 | time 460[s] | loss 0.15
# | epoch 11 |  iters 61 / 351 | time 462[s] | loss 0.15
# | epoch 11 |  iters 81 / 351 | time 464[s] | loss 0.15
# | epoch 11 |  iters 101 / 351 | time 466[s] | loss 0.14
# | epoch 11 |  iters 121 / 351 | time 468[s] | loss 0.14
# | epoch 11 |  iters 141 / 351 | time 469[s] | loss 0.14
# | epoch 11 |  iters 161 / 351 | time 471[s] | loss 0.14
# | epoch 11 |  iters 181 / 351 | time 473[s] | loss 0.14
# | epoch 11 |  iters 201 / 351 | time 474[s] | loss 0.14
# | epoch 11 |  iters 221 / 351 | time 476[s] | loss 0.13
# | epoch 11 |  iters 241 / 351 | time 478[s] | loss 0.13
# | epoch 11 |  iters 261 / 351 | time 479[s] | loss 0.12
# | epoch 11 |  iters 281 / 351 | time 481[s] | loss 0.12
# | epoch 11 |  iters 301 / 351 | time 483[s] | loss 0.13
# | epoch 11 |  iters 321 / 351 | time 485[s] | loss 0.12
# | epoch 11 |  iters 341 / 351 | time 487[s] | loss 0.12
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# accuracy 90.280%
# | epoch 12 |  iters 1 / 351 | time 513[s] | loss 0.12
# | epoch 12 |  iters 21 / 351 | time 516[s] | loss 0.11
# | epoch 12 |  iters 41 / 351 | time 519[s] | loss 0.11
# | epoch 12 |  iters 61 / 351 | time 521[s] | loss 0.11
# | epoch 12 |  iters 81 / 351 | time 523[s] | loss 0.11
# | epoch 12 |  iters 101 / 351 | time 526[s] | loss 0.11
# | epoch 12 |  iters 121 / 351 | time 528[s] | loss 0.10
# | epoch 12 |  iters 141 / 351 | time 530[s] | loss 0.10
# | epoch 12 |  iters 161 / 351 | time 533[s] | loss 0.10
# | epoch 12 |  iters 181 / 351 | time 536[s] | loss 0.11
# | epoch 12 |  iters 201 / 351 | time 538[s] | loss 0.10
# | epoch 12 |  iters 221 / 351 | time 540[s] | loss 0.10
# | epoch 12 |  iters 241 / 351 | time 543[s] | loss 0.10
# | epoch 12 |  iters 261 / 351 | time 546[s] | loss 0.10
# | epoch 12 |  iters 281 / 351 | time 548[s] | loss 0.10
# | epoch 12 |  iters 301 / 351 | time 550[s] | loss 0.10
# | epoch 12 |  iters 321 / 351 | time 554[s] | loss 0.09
# | epoch 12 |  iters 341 / 351 | time 557[s] | loss 0.09
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# accuracy 93.220%
# | epoch 13 |  iters 1 / 351 | time 585[s] | loss 0.10
# | epoch 13 |  iters 21 / 351 | time 588[s] | loss 0.09
# | epoch 13 |  iters 41 / 351 | time 591[s] | loss 0.09
# | epoch 13 |  iters 61 / 351 | time 594[s] | loss 0.09
# | epoch 13 |  iters 81 / 351 | time 596[s] | loss 0.08
# | epoch 13 |  iters 101 / 351 | time 599[s] | loss 0.08
# | epoch 13 |  iters 121 / 351 | time 601[s] | loss 0.08
# | epoch 13 |  iters 141 / 351 | time 603[s] | loss 0.08
# | epoch 13 |  iters 161 / 351 | time 605[s] | loss 0.08
# | epoch 13 |  iters 181 / 351 | time 608[s] | loss 0.08
# | epoch 13 |  iters 201 / 351 | time 610[s] | loss 0.08
# | epoch 13 |  iters 221 / 351 | time 611[s] | loss 0.08
# | epoch 13 |  iters 241 / 351 | time 613[s] | loss 0.08
# | epoch 13 |  iters 261 / 351 | time 615[s] | loss 0.08
# | epoch 13 |  iters 281 / 351 | time 616[s] | loss 0.07
# | epoch 13 |  iters 301 / 351 | time 618[s] | loss 0.08
# | epoch 13 |  iters 321 / 351 | time 620[s] | loss 0.07
# | epoch 13 |  iters 341 / 351 | time 621[s] | loss 0.07
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# accuracy 93.520%
# | epoch 14 |  iters 1 / 351 | time 635[s] | loss 0.07
# | epoch 14 |  iters 21 / 351 | time 637[s] | loss 0.07
# | epoch 14 |  iters 41 / 351 | time 638[s] | loss 0.07
# | epoch 14 |  iters 61 / 351 | time 640[s] | loss 0.07
# | epoch 14 |  iters 81 / 351 | time 642[s] | loss 0.07
# | epoch 14 |  iters 101 / 351 | time 643[s] | loss 0.06
# | epoch 14 |  iters 121 / 351 | time 645[s] | loss 0.07
# | epoch 14 |  iters 141 / 351 | time 647[s] | loss 0.06
# | epoch 14 |  iters 161 / 351 | time 648[s] | loss 0.07
# | epoch 14 |  iters 181 / 351 | time 650[s] | loss 0.07
# | epoch 14 |  iters 201 / 351 | time 652[s] | loss 0.06
# | epoch 14 |  iters 221 / 351 | time 653[s] | loss 0.07
# | epoch 14 |  iters 241 / 351 | time 655[s] | loss 0.06
# | epoch 14 |  iters 261 / 351 | time 656[s] | loss 0.06
# | epoch 14 |  iters 281 / 351 | time 658[s] | loss 0.06
# | epoch 14 |  iters 301 / 351 | time 660[s] | loss 0.06
# | epoch 14 |  iters 321 / 351 | time 662[s] | loss 0.06
# | epoch 14 |  iters 341 / 351 | time 663[s] | loss 0.06
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# accuracy 95.440%
# | epoch 15 |  iters 1 / 351 | time 677[s] | loss 0.06
# | epoch 15 |  iters 21 / 351 | time 678[s] | loss 0.06
# | epoch 15 |  iters 41 / 351 | time 680[s] | loss 0.06
# | epoch 15 |  iters 61 / 351 | time 681[s] | loss 0.05
# | epoch 15 |  iters 81 / 351 | time 683[s] | loss 0.06
# | epoch 15 |  iters 101 / 351 | time 684[s] | loss 0.06
# | epoch 15 |  iters 121 / 351 | time 686[s] | loss 0.06
# | epoch 15 |  iters 141 / 351 | time 687[s] | loss 0.05
# | epoch 15 |  iters 161 / 351 | time 689[s] | loss 0.05
# | epoch 15 |  iters 181 / 351 | time 691[s] | loss 0.05
# | epoch 15 |  iters 201 / 351 | time 692[s] | loss 0.05
# | epoch 15 |  iters 221 / 351 | time 694[s] | loss 0.05
# | epoch 15 |  iters 241 / 351 | time 695[s] | loss 0.05
# | epoch 15 |  iters 261 / 351 | time 697[s] | loss 0.05
# | epoch 15 |  iters 281 / 351 | time 699[s] | loss 0.05
# | epoch 15 |  iters 301 / 351 | time 700[s] | loss 0.05
# | epoch 15 |  iters 321 / 351 | time 702[s] | loss 0.05
# | epoch 15 |  iters 341 / 351 | time 703[s] | loss 0.05
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# X 1043
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# accuracy 89.740%
# | epoch 16 |  iters 1 / 351 | time 716[s] | loss 0.06
# | epoch 16 |  iters 21 / 351 | time 717[s] | loss 0.05
# | epoch 16 |  iters 41 / 351 | time 719[s] | loss 0.05
# | epoch 16 |  iters 61 / 351 | time 720[s] | loss 0.05
# | epoch 16 |  iters 81 / 351 | time 722[s] | loss 0.05
# | epoch 16 |  iters 101 / 351 | time 724[s] | loss 0.05
# | epoch 16 |  iters 121 / 351 | time 725[s] | loss 0.04
# | epoch 16 |  iters 141 / 351 | time 727[s] | loss 0.04
# | epoch 16 |  iters 161 / 351 | time 728[s] | loss 0.05
# | epoch 16 |  iters 181 / 351 | time 730[s] | loss 0.05
# | epoch 16 |  iters 201 / 351 | time 732[s] | loss 0.04
# | epoch 16 |  iters 221 / 351 | time 733[s] | loss 0.04
# | epoch 16 |  iters 241 / 351 | time 735[s] | loss 0.04
# | epoch 16 |  iters 261 / 351 | time 737[s] | loss 0.05
# | epoch 16 |  iters 281 / 351 | time 738[s] | loss 0.05
# | epoch 16 |  iters 301 / 351 | time 740[s] | loss 0.04
# | epoch 16 |  iters 321 / 351 | time 741[s] | loss 0.04
# | epoch 16 |  iters 341 / 351 | time 743[s] | loss 0.04
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# accuracy 96.100%
# | epoch 17 |  iters 1 / 351 | time 755[s] | loss 0.04
# | epoch 17 |  iters 21 / 351 | time 757[s] | loss 0.04
# | epoch 17 |  iters 41 / 351 | time 758[s] | loss 0.04
# | epoch 17 |  iters 61 / 351 | time 760[s] | loss 0.04
# | epoch 17 |  iters 81 / 351 | time 761[s] | loss 0.04
# | epoch 17 |  iters 101 / 351 | time 763[s] | loss 0.04
# | epoch 17 |  iters 121 / 351 | time 764[s] | loss 0.04
# | epoch 17 |  iters 141 / 351 | time 766[s] | loss 0.04
# | epoch 17 |  iters 161 / 351 | time 767[s] | loss 0.04
# | epoch 17 |  iters 181 / 351 | time 769[s] | loss 0.04
# | epoch 17 |  iters 201 / 351 | time 771[s] | loss 0.04
# | epoch 17 |  iters 221 / 351 | time 772[s] | loss 0.04
# | epoch 17 |  iters 241 / 351 | time 774[s] | loss 0.04
# | epoch 17 |  iters 261 / 351 | time 775[s] | loss 0.04
# | epoch 17 |  iters 281 / 351 | time 777[s] | loss 0.04
# | epoch 17 |  iters 301 / 351 | time 779[s] | loss 0.03
# | epoch 17 |  iters 321 / 351 | time 780[s] | loss 0.04
# | epoch 17 |  iters 341 / 351 | time 782[s] | loss 0.04
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# accuracy 96.000%
# | epoch 18 |  iters 1 / 351 | time 794[s] | loss 0.04
# | epoch 18 |  iters 21 / 351 | time 796[s] | loss 0.04
# | epoch 18 |  iters 41 / 351 | time 798[s] | loss 0.04
# | epoch 18 |  iters 61 / 351 | time 800[s] | loss 0.04
# | epoch 18 |  iters 81 / 351 | time 802[s] | loss 0.04
# | epoch 18 |  iters 101 / 351 | time 805[s] | loss 0.04
# | epoch 18 |  iters 121 / 351 | time 807[s] | loss 0.04
# | epoch 18 |  iters 141 / 351 | time 809[s] | loss 0.04
# | epoch 18 |  iters 161 / 351 | time 810[s] | loss 0.03
# | epoch 18 |  iters 181 / 351 | time 812[s] | loss 0.03
# | epoch 18 |  iters 201 / 351 | time 814[s] | loss 0.04
# | epoch 18 |  iters 221 / 351 | time 815[s] | loss 0.03
# | epoch 18 |  iters 241 / 351 | time 817[s] | loss 0.04
# | epoch 18 |  iters 261 / 351 | time 819[s] | loss 0.04
# | epoch 18 |  iters 281 / 351 | time 820[s] | loss 0.03
# | epoch 18 |  iters 301 / 351 | time 822[s] | loss 0.03
# | epoch 18 |  iters 321 / 351 | time 823[s] | loss 0.03
# | epoch 18 |  iters 341 / 351 | time 825[s] | loss 0.04
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# accuracy 96.400%
# | epoch 19 |  iters 1 / 351 | time 837[s] | loss 0.03
# | epoch 19 |  iters 21 / 351 | time 839[s] | loss 0.03
# | epoch 19 |  iters 41 / 351 | time 841[s] | loss 0.03
# | epoch 19 |  iters 61 / 351 | time 842[s] | loss 0.03
# | epoch 19 |  iters 81 / 351 | time 844[s] | loss 0.03
# | epoch 19 |  iters 101 / 351 | time 845[s] | loss 0.03
# | epoch 19 |  iters 121 / 351 | time 847[s] | loss 0.03
# | epoch 19 |  iters 141 / 351 | time 849[s] | loss 0.03
# | epoch 19 |  iters 161 / 351 | time 851[s] | loss 0.03
# | epoch 19 |  iters 181 / 351 | time 854[s] | loss 0.03
# | epoch 19 |  iters 201 / 351 | time 856[s] | loss 0.03
# | epoch 19 |  iters 221 / 351 | time 858[s] | loss 0.03
# | epoch 19 |  iters 241 / 351 | time 860[s] | loss 0.03
# | epoch 19 |  iters 261 / 351 | time 863[s] | loss 0.03
# | epoch 19 |  iters 281 / 351 | time 865[s] | loss 0.03
# | epoch 19 |  iters 301 / 351 | time 867[s] | loss 0.03
# | epoch 19 |  iters 321 / 351 | time 868[s] | loss 0.04
# | epoch 19 |  iters 341 / 351 | time 870[s] | loss 0.03
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# accuracy 97.860%
# | epoch 20 |  iters 1 / 351 | time 890[s] | loss 0.02
# | epoch 20 |  iters 21 / 351 | time 892[s] | loss 0.02
# | epoch 20 |  iters 41 / 351 | time 894[s] | loss 0.03
# | epoch 20 |  iters 61 / 351 | time 897[s] | loss 0.03
# | epoch 20 |  iters 81 / 351 | time 899[s] | loss 0.03
# | epoch 20 |  iters 101 / 351 | time 901[s] | loss 0.02
# | epoch 20 |  iters 121 / 351 | time 903[s] | loss 0.03
# | epoch 20 |  iters 141 / 351 | time 905[s] | loss 0.04
# | epoch 20 |  iters 161 / 351 | time 907[s] | loss 0.03
# | epoch 20 |  iters 181 / 351 | time 910[s] | loss 0.03
# | epoch 20 |  iters 201 / 351 | time 912[s] | loss 0.03
# | epoch 20 |  iters 221 / 351 | time 914[s] | loss 0.03
# | epoch 20 |  iters 241 / 351 | time 916[s] | loss 0.03
# | epoch 20 |  iters 261 / 351 | time 917[s] | loss 0.02
# | epoch 20 |  iters 281 / 351 | time 919[s] | loss 0.03
# | epoch 20 |  iters 301 / 351 | time 921[s] | loss 0.02
# | epoch 20 |  iters 321 / 351 | time 922[s] | loss 0.02
# | epoch 20 |  iters 341 / 351 | time 924[s] | loss 0.03
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# X 1052
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# accuracy 95.220%
# | epoch 21 |  iters 1 / 351 | time 942[s] | loss 0.04
# | epoch 21 |  iters 21 / 351 | time 944[s] | loss 0.02
# | epoch 21 |  iters 41 / 351 | time 946[s] | loss 0.02
# | epoch 21 |  iters 61 / 351 | time 948[s] | loss 0.02
# | epoch 21 |  iters 81 / 351 | time 949[s] | loss 0.02
# | epoch 21 |  iters 101 / 351 | time 951[s] | loss 0.03
# | epoch 21 |  iters 121 / 351 | time 953[s] | loss 0.03
# | epoch 21 |  iters 141 / 351 | time 955[s] | loss 0.03
# | epoch 21 |  iters 161 / 351 | time 956[s] | loss 0.02
# | epoch 21 |  iters 181 / 351 | time 958[s] | loss 0.03
# | epoch 21 |  iters 201 / 351 | time 960[s] | loss 0.03
# | epoch 21 |  iters 221 / 351 | time 961[s] | loss 0.03
# | epoch 21 |  iters 241 / 351 | time 963[s] | loss 0.02
# | epoch 21 |  iters 261 / 351 | time 965[s] | loss 0.03
# | epoch 21 |  iters 281 / 351 | time 966[s] | loss 0.03
# | epoch 21 |  iters 301 / 351 | time 968[s] | loss 0.03
# | epoch 21 |  iters 321 / 351 | time 970[s] | loss 0.02
# | epoch 21 |  iters 341 / 351 | time 972[s] | loss 0.03
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# accuracy 96.540%
# | epoch 22 |  iters 1 / 351 | time 987[s] | loss 0.03
# | epoch 22 |  iters 21 / 351 | time 989[s] | loss 0.02
# | epoch 22 |  iters 41 / 351 | time 991[s] | loss 0.02
# | epoch 22 |  iters 61 / 351 | time 993[s] | loss 0.03
# | epoch 22 |  iters 81 / 351 | time 995[s] | loss 0.02
# | epoch 22 |  iters 101 / 351 | time 997[s] | loss 0.02
# | epoch 22 |  iters 121 / 351 | time 999[s] | loss 0.02
# | epoch 22 |  iters 141 / 351 | time 1001[s] | loss 0.02
# | epoch 22 |  iters 161 / 351 | time 1003[s] | loss 0.02
# | epoch 22 |  iters 181 / 351 | time 1004[s] | loss 0.02
# | epoch 22 |  iters 201 / 351 | time 1006[s] | loss 0.02
# | epoch 22 |  iters 221 / 351 | time 1008[s] | loss 0.02
# | epoch 22 |  iters 241 / 351 | time 1009[s] | loss 0.02
# | epoch 22 |  iters 261 / 351 | time 1011[s] | loss 0.02
# | epoch 22 |  iters 281 / 351 | time 1013[s] | loss 0.03
# | epoch 22 |  iters 301 / 351 | time 1015[s] | loss 0.03
# | epoch 22 |  iters 321 / 351 | time 1017[s] | loss 0.02
# | epoch 22 |  iters 341 / 351 | time 1018[s] | loss 0.03
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# accuracy 96.600%
# | epoch 23 |  iters 1 / 351 | time 1038[s] | loss 0.02
# | epoch 23 |  iters 21 / 351 | time 1040[s] | loss 0.02
# | epoch 23 |  iters 41 / 351 | time 1042[s] | loss 0.02
# | epoch 23 |  iters 61 / 351 | time 1044[s] | loss 0.02
# | epoch 23 |  iters 81 / 351 | time 1046[s] | loss 0.02
# | epoch 23 |  iters 101 / 351 | time 1047[s] | loss 0.02
# | epoch 23 |  iters 121 / 351 | time 1049[s] | loss 0.02
# | epoch 23 |  iters 141 / 351 | time 1052[s] | loss 0.02
# | epoch 23 |  iters 161 / 351 | time 1054[s] | loss 0.02
# | epoch 23 |  iters 181 / 351 | time 1055[s] | loss 0.02
# | epoch 23 |  iters 201 / 351 | time 1058[s] | loss 0.02
# | epoch 23 |  iters 221 / 351 | time 1060[s] | loss 0.02
# | epoch 23 |  iters 241 / 351 | time 1062[s] | loss 0.03
# | epoch 23 |  iters 261 / 351 | time 1064[s] | loss 0.03
# | epoch 23 |  iters 281 / 351 | time 1065[s] | loss 0.02
# | epoch 23 |  iters 301 / 351 | time 1068[s] | loss 0.02
# | epoch 23 |  iters 321 / 351 | time 1070[s] | loss 0.03
# | epoch 23 |  iters 341 / 351 | time 1071[s] | loss 0.03
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# accuracy 96.700%
# | epoch 24 |  iters 1 / 351 | time 1087[s] | loss 0.02
# | epoch 24 |  iters 21 / 351 | time 1088[s] | loss 0.02
# | epoch 24 |  iters 41 / 351 | time 1090[s] | loss 0.02
# | epoch 24 |  iters 61 / 351 | time 1092[s] | loss 0.02
# | epoch 24 |  iters 81 / 351 | time 1094[s] | loss 0.02
# | epoch 24 |  iters 101 / 351 | time 1095[s] | loss 0.02
# | epoch 24 |  iters 121 / 351 | time 1097[s] | loss 0.02
# | epoch 24 |  iters 141 / 351 | time 1099[s] | loss 0.02
# | epoch 24 |  iters 161 / 351 | time 1101[s] | loss 0.02
# | epoch 24 |  iters 181 / 351 | time 1103[s] | loss 0.02
# | epoch 24 |  iters 201 / 351 | time 1105[s] | loss 0.03
# | epoch 24 |  iters 221 / 351 | time 1107[s] | loss 0.02
# | epoch 24 |  iters 241 / 351 | time 1109[s] | loss 0.02
# | epoch 24 |  iters 261 / 351 | time 1111[s] | loss 0.02
# | epoch 24 |  iters 281 / 351 | time 1112[s] | loss 0.02
# | epoch 24 |  iters 301 / 351 | time 1114[s] | loss 0.02
# | epoch 24 |  iters 321 / 351 | time 1116[s] | loss 0.02
# | epoch 24 |  iters 341 / 351 | time 1118[s] | loss 0.02
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# accuracy 95.840%
# | epoch 25 |  iters 1 / 351 | time 1134[s] | loss 0.02
# | epoch 25 |  iters 21 / 351 | time 1135[s] | loss 0.02
# | epoch 25 |  iters 41 / 351 | time 1137[s] | loss 0.02
# | epoch 25 |  iters 61 / 351 | time 1139[s] | loss 0.02
# | epoch 25 |  iters 81 / 351 | time 1140[s] | loss 0.02
# | epoch 25 |  iters 101 / 351 | time 1142[s] | loss 0.02
# | epoch 25 |  iters 121 / 351 | time 1144[s] | loss 0.02
# | epoch 25 |  iters 141 / 351 | time 1146[s] | loss 0.02
# | epoch 25 |  iters 161 / 351 | time 1148[s] | loss 0.02
# | epoch 25 |  iters 181 / 351 | time 1151[s] | loss 0.02
# | epoch 25 |  iters 201 / 351 | time 1152[s] | loss 0.02
# | epoch 25 |  iters 221 / 351 | time 1154[s] | loss 0.02
# | epoch 25 |  iters 241 / 351 | time 1156[s] | loss 0.02
# | epoch 25 |  iters 261 / 351 | time 1158[s] | loss 0.02
# | epoch 25 |  iters 281 / 351 | time 1160[s] | loss 0.03
# | epoch 25 |  iters 301 / 351 | time 1162[s] | loss 0.02
# | epoch 25 |  iters 321 / 351 | time 1164[s] | loss 0.02
# | epoch 25 |  iters 341 / 351 | time 1166[s] | loss 0.02
# Q   58+77
# T 162
# O 162
# ---
# Q 461+579
# T 1139
# O 1139
# ---
# Q  48+285
# T 666
# O 666
# ---
# Q   551+8
# T 163
# O 163
# ---
# Q  55+763
# T 422
# O 422
# ---
# Q 752+006
# T 857
# O 857
# ---
# Q 292+167
# T 1053
# O 1053
# ---
# Q 795+038
# T 1427
# O 1427
# ---
# Q  838+62
# T 864
# O 864
# ---
# Q  39+341
# T 236
# O 236
# ---
# accuracy 96.100%

# %%
acc = np.arange(len(acc_list))
plt.plot(acc, acc_list, label='train')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.show()
